# %% [markdown]
# ## 🌐 Leveraging APIs for Real-Time Cryptocurrency Data 🚀

# %%
import requests
import json
import pandas as pd
from datetime import datetime

url = "https://api.coingecko.com/api/v3/coins/markets"
params = {
    'vs_currency': 'usd',  
    'order': 'market_cap_desc', 
    'per_page': 10, 
    'page': 1,  
    'sparkline': 'false', 
    'price_change_percentage': '1h,24h,7d' 
}

# Fetching data from the API
response = requests.get(url, params=params)
data = response.json()

# Saving data into a list
cryptos = []
for coin in data:
    cryptos.append({
        'Name': coin['name'],
        'Symbol': coin['symbol'],
        'Current Price (USD)': coin['current_price'],
        'Market Cap (USD)': coin['market_cap'],
        '24h Volume (USD)': coin['total_volume'],
        '24h Price Change (%)': coin['price_change_percentage_24h'],
        '1h Price Change (%)': coin.get('price_change_percentage_1h_in_currency', 'N/A'),  
        '7d Price Change (%)': coin.get('price_change_percentage_7d_in_currency', 'N/A')   
    })

# Converting list data into a DataFrame
df = pd.DataFrame(cryptos)

# Add a timestamp for reference
timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
df['Timestamp'] = timestamp

# Saving Data into a .CSV file
df.to_csv(r'C:\Users\LOGIN-SOLUTIOn\Documents\Data_Analyst\DataSets_+sql\csv_files\crypto_prices.csv', index=False)

# %%
df
# Out:
#                 Name Symbol  Current Price (USD)  Market Cap (USD)  \
# 0            Bitcoin    btc           54483.0000     1075187640115
# 1           Ethereum    eth            2278.6500      273942163402
# 2             Tether   usdt               1.0000      118229090853
# 3                BNB    bnb             496.8700       72435141700
# 4             Solana    sol             128.9400       60291985263
# 5               USDC   usdc               1.0000       34969582828
# 6                XRP    xrp               0.5267       29666155022
# 7  Lido Staked Ether  steth            2274.5800       22313070898
# 8           Dogecoin   doge               0.0956       13920346703
# 9               TRON    trx               0.1531       13271595168
#
#    24h Volume (USD)  24h Price Change (%)  1h Price Change (%)  \
# 0       15883950007                0.2681               0.2375
# 1        8765909310               -0.3038               0.1920
# 2       22321798812               -0.0473               0.0324
# 3         562679047                0.3744              -0.0399
# 4        1498975516                0.8911               0.0746
# 5        3450491877                0.0259               0.0470
# 6         500700331               -0.4544               0.1811
# 7          62604944               -0.3998               0.1025
# 8         413352450                0.7889               0.3276
# 9         407082761                1.1319               0.1204
#
#    7d Price Change (%)            Timestamp
# 0              -6.3021  2024-09-09 00:23:42
# 1              -7.7962  2024-09-09 00:23:42
# 2              -0.0800  2024-09-09 00:23:42
# 3              -4.3555  2024-09-09 00:23:42
# 4              -2.9888  2024-09-09 00:23:42
# 5               0.0640  2024-09-09 00:23:42
# 6              -5.1548  2024-09-09 00:23:42
# 7              -8.0373  2024-09-09 00:23:42
# 8              -2.3954  2024-09-09 00:23:42
# 9              -2.2897  2024-09-09 00:23:42

# %% [markdown]
# #                                               Automating Cryptocurrency Data Retrieval

# %%
import pandas as pd
import requests
import json
from datetime import datetime


df = pd.DataFrame()

def API_Runner():
    global df  

    url = "https://api.coingecko.com/api/v3/coins/markets"
    params = {
        'vs_currency': 'usd',  
        'order': 'market_cap_desc', 
        'per_page': 10,  
        'page': 1, 
        'sparkline': 'false', 
        'price_change_percentage': '1h,24h,7d' 
    }
    
    # Fetch data from the API
    response = requests.get(url, params=params)
    data = response.json()
    
    # Saving data into a list
    cryptos = []
    for coin in data:
        cryptos.append({
            'Name': coin['name'],
            'Symbol': coin['symbol'],
            'Current Price (USD)': coin['current_price'],
            'Market Cap (USD)': coin['market_cap'],
            '24h Volume (USD)': coin['total_volume'],
            '24h Price Change (%)': coin['price_change_percentage_24h'],
            '1h Price Change (%)': coin.get('price_change_percentage_1h_in_currency', 'N/A'),  # 1h change
            '7d Price Change (%)': coin.get('price_change_percentage_7d_in_currency', 'N/A')   # 7d change
        })
    
    # Converting list data into a DataFrame
    df = pd.DataFrame(cryptos)
    
    # Add a timestamp for reference
    timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    df['Timestamp'] = timestamp

   # Save the dataframe to a CSV file or perform other operations as needed
    if not os.path.isfile(r'C:\Users\LOGIN-SOLUTIOn\Documents\Data_Analyst\DataSets_+sql\csv_files\crypto_prices.csv'):
        df.to_csv(r'C:\Users\LOGIN-SOLUTIOn\Documents\Data_Analyst\DataSets_+sql\csv_files\crypto_prices.csv',index=False)
    else:
        df.to_csv(r'C:\Users\LOGIN-SOLUTIOn\Documents\Data_Analyst\DataSets_+sql\csv_files\crypto_prices.csv',mode='a',header=False,index=False)

# %%
import os 
from datetime import datetime
from time import time
from time import sleep

for i in range(3):     # 333 is the limit of using this API in a day!
    API_Runner()
    print("Run Sucessfully")
    sleep(12) 

exit()
# Out:
# Run Sucessfully
# Run Sucessfully
# Run Sucessfully

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\LOGIN-SOLUTIOn\Documents\Data_Analyst\DataSets_+sql\csv_files\crypto_prices.csv')

# %%
df['1h Volume ']

# %%
pd.set_option('display.float_format',lambda x: '%.4f' % x)      # Setting all float values upto 4 decimals

# %%
df
# Out:
#                  Name Symbol  Current Price (USD)  Market Cap (USD)  \
# 0             Bitcoin    btc           54483.0000     1075187640115
# 1            Ethereum    eth            2278.6500      273942163402
# 2              Tether   usdt               1.0000      118229090853
# 3                 BNB    bnb             496.8700       72435141700
# 4              Solana    sol             128.9400       60291985263
# 5                USDC   usdc               1.0000       34969582828
# 6                 XRP    xrp               0.5267       29666155022
# 7   Lido Staked Ether  steth            2274.5800       22313070898
# 8            Dogecoin   doge               0.0956       13920346703
# 9                TRON    trx               0.1531       13271595168
# 10            Bitcoin    btc           54483.0000     1075187640115
# 11           Ethereum    eth            2278.6500      273942163402
# 12             Tether   usdt               1.0000      118229090853
# 13                BNB    bnb             496.8700       72435141700
# 14             Solana    sol             128.9400       60291985263
# 15               USDC   usdc               1.0000       34969582828
# 16                XRP    xrp               0.5267       29666155022
# 17  Lido Staked Ether  steth            2274.5800       22313070898
# 18           Dogecoin   doge               0.0956       13920346703
# 19               TRON    trx               0.1531       13271595168
# 20            Bitcoin    btc           54483.0000     1075187640115
# 21           Ethereum    eth            2278.6500      273942163402
# 22             Tether   usdt               1.0000      118229090853
# 23                BNB    bnb             496.8700       72435141700
# 24             Solana    sol             128.9400       60291985263
# 25               USDC   usdc               1.0000       34969582828
# 26                XRP    xrp               0.5267       29666155022
# 27  Lido Staked Ether  steth            2274.5800       22313070898
# 28           Dogecoin   doge               0.0956       13920346703
# 29               TRON    trx               0.1531       13271595168
# 30            Bitcoin    btc           54483.0000     1075187640115
# 31           Ethereum    eth            2278.6500      273942163402
# 32             Tether   usdt               1.0000      118229090853
# 33                BNB    bnb             496.8700       72435141700
# 34             Solana    sol             128.9400       60291985263
# 35               USDC   usdc               1.0000       34969582828
# 36                XRP    xrp               0.5267       29666155022
# 37  Lido Staked Ether  steth            2274.5800       22313070898
# 38           Dogecoin   doge               0.0956       13920346703
# 39               TRON    trx               0.1531       13271595168
#
#     24h Volume (USD)  24h Price Change (%)  1h Price Change (%)  \
# 0        15883950007                0.2681               0.2375
# 1         8765909310               -0.3038               0.1920
# 2        22321798812               -0.0473               0.0324
# 3          562679047                0.3744              -0.0399
# 4         1498975516                0.8911               0.0746
# 5         3450491877                0.0259               0.0470
# 6          500700331               -0.4544               0.1811
# 7           62604944               -0.3998               0.1025
# 8          413352450                0.7889               0.3276
# 9          407082761                1.1319               0.1204
# 10       15883950007                0.2681               0.2375
# 11        8765909310               -0.3038               0.1920
# 12       22321798812               -0.0473               0.0324
# 13         562679047                0.3744              -0.0399
# 14        1498975516                0.8911               0.0746
# 15        3450491877                0.0259               0.0470
# 16         500700331               -0.4544               0.1811
# 17          62604944               -0.3998               0.1025
# 18         413352450                0.7889               0.3276
# 19         407082761                1.1319               0.1204
# 20       15883950007                0.2681               0.2375
# 21        8765909310               -0.3038               0.1920
# 22       22321798812               -0.0473               0.0324
# 23         562679047                0.3744              -0.0399
# 24        1498975516                0.8911               0.0746
# 25        3450491877                0.0259               0.0470
# 26         500700331               -0.4544               0.1811
# 27          62604944               -0.3998               0.1025
# 28         413352450                0.7889               0.3276
# 29         407082761                1.1319               0.1204
# 30       15883950007                0.2681               0.2375
# 31        8765909310               -0.3038               0.1920
# 32       22321798812               -0.0473               0.0324
# 33         562679047                0.3744              -0.0399
# 34        1498975516                0.8911               0.0746
# 35        3450491877                0.0259               0.0470
# 36         500700331               -0.4544               0.1811
# 37          62604944               -0.3998               0.1025
# 38         413352450                0.7889               0.3276
# 39         407082761                1.1319               0.1204
#
#     7d Price Change (%)            Timestamp
# 0               -6.3021  2024-09-09 00:23:42
# 1               -7.7962  2024-09-09 00:23:42
# 2               -0.0800  2024-09-09 00:23:42
# 3               -4.3555  2024-09-09 00:23:42
# 4               -2.9888  2024-09-09 00:23:42
# 5                0.0640  2024-09-09 00:23:42
# 6               -5.1548  2024-09-09 00:23:42
# 7               -8.0373  2024-09-09 00:23:42
# 8               -2.3954  2024-09-09 00:23:42
# 9               -2.2897  2024-09-09 00:23:42
# 10              -6.3021  2024-09-09 00:24:36
# 11              -7.7962  2024-09-09 00:24:36
# 12              -0.0800  2024-09-09 00:24:36
# 13              -4.3555  2024-09-09 00:24:36
# 14              -2.9888  2024-09-09 00:24:36
# 15               0.0640  2024-09-09 00:24:36
# 16              -5.1548  2024-09-09 00:24:36
# 17              -8.0373  2024-09-09 00:24:36
# 18              -2.3954  2024-09-09 00:24:36
# 19              -2.2897  2024-09-09 00:24:36
# 20              -6.3021  2024-09-09 00:24:48
# 21              -7.7962  2024-09-09 00:24:48
# 22              -0.0800  2024-09-09 00:24:48
# 23              -4.3555  2024-09-09 00:24:48
# 24              -2.9888  2024-09-09 00:24:48
# 25               0.0640  2024-09-09 00:24:48
# 26              -5.1548  2024-09-09 00:24:48
# 27              -8.0373  2024-09-09 00:24:48
# 28              -2.3954  2024-09-09 00:24:48
# 29              -2.2897  2024-09-09 00:24:48
# 30              -6.3021  2024-09-09 00:25:01
# 31              -7.7962  2024-09-09 00:25:01
# 32              -0.0800  2024-09-09 00:25:01
# 33              -4.3555  2024-09-09 00:25:01
# 34              -2.9888  2024-09-09 00:25:01
# 35               0.0640  2024-09-09 00:25:01
# 36              -5.1548  2024-09-09 00:25:01
# 37              -8.0373  2024-09-09 00:25:01
# 38              -2.3954  2024-09-09 00:25:01
# 39              -2.2897  2024-09-09 00:25:01

# %%
df.columns
# Out:
# Index(['Name', 'Symbol', 'Current Price (USD)', 'Market Cap (USD)',
#        '24h Volume (USD)', '24h Price Change (%)', '1h Price Change (%)',
#        '7d Price Change (%)', 'Timestamp'],
#       dtype='object')

# %%
df2 = df.groupby('Name',sort=False)[['1h Price Change (%)','24h Price Change (%)','7d Price Change (%)']].mean()
df2
# Out:
#                    1h Price Change (%)  24h Price Change (%)  \
# Name
# Bitcoin                         0.2375                0.2681
# Ethereum                        0.1920               -0.3038
# Tether                          0.0324               -0.0473
# BNB                            -0.0399                0.3744
# Solana                          0.0746                0.8911
# USDC                            0.0470                0.0259
# XRP                             0.1811               -0.4544
# Lido Staked Ether               0.1025               -0.3998
# Dogecoin                        0.3276                0.7889
# TRON                            0.1204                1.1319
#
#                    7d Price Change (%)
# Name
# Bitcoin                        -6.3021
# Ethereum                       -7.7962
# Tether                         -0.0800
# BNB                            -4.3555
# Solana                         -2.9888
# USDC                            0.0640
# XRP                            -5.1548
# Lido Staked Ether              -8.0373
# Dogecoin                       -2.3954
# TRON                           -2.2897

# %%
df3 = df2.stack()
df3
# Out:
# Name
# Bitcoin            1h Price Change (%)     0.2375
#                    24h Price Change (%)    0.2681
#                    7d Price Change (%)    -6.3021
# Ethereum           1h Price Change (%)     0.1920
#                    24h Price Change (%)   -0.3038
#                    7d Price Change (%)    -7.7962
# Tether             1h Price Change (%)     0.0324
#                    24h Price Change (%)   -0.0473
#                    7d Price Change (%)    -0.0800
# BNB                1h Price Change (%)    -0.0399
#                    24h Price Change (%)    0.3744
#                    7d Price Change (%)    -4.3555
# Solana             1h Price Change (%)     0.0746
#                    24h Price Change (%)    0.8911
#                    7d Price Change (%)    -2.9888
# USDC               1h Price Change (%)     0.0470
#                    24h Price Change (%)    0.0259
#                    7d Price Change (%)     0.0640
# XRP                1h Price Change (%)     0.1811
#                    24h Price Change (%)   -0.4544
#                    7d Price Change (%)    -5.1548
# Lido Staked Ether  1h Price Change (%)     0.1025
#                    24h Price Change (%)   -0.3998
#                    7d Price Change (%)    -8.0373
# Dogecoin           1h Price Change (%)     0.3276
#                    24h Price Change (%)    0.7889
#                    7d Price Change (%)    -2.3954
# TRON               1h Price Change (%)     0.1204
#                    24h Price Change (%)    1.1319
#                    7d Price Change (%)    -2.2897
# dtype: float64

# %%
df4 = df3.to_frame(name='Values')
df4
# Out:
#                                         Values
# Name
# Bitcoin           1h Price Change (%)   0.2375
#                   24h Price Change (%)  0.2681
#                   7d Price Change (%)  -6.3021
# Ethereum          1h Price Change (%)   0.1920
#                   24h Price Change (%) -0.3038
#                   7d Price Change (%)  -7.7962
# Tether            1h Price Change (%)   0.0324
#                   24h Price Change (%) -0.0473
#                   7d Price Change (%)  -0.0800
# BNB               1h Price Change (%)  -0.0399
#                   24h Price Change (%)  0.3744
#                   7d Price Change (%)  -4.3555
# Solana            1h Price Change (%)   0.0746
#                   24h Price Change (%)  0.8911
#                   7d Price Change (%)  -2.9888
# USDC              1h Price Change (%)   0.0470
#                   24h Price Change (%)  0.0259
#                   7d Price Change (%)   0.0640
# XRP               1h Price Change (%)   0.1811
#                   24h Price Change (%) -0.4544
#                   7d Price Change (%)  -5.1548
# Lido Staked Ether 1h Price Change (%)   0.1025
#                   24h Price Change (%) -0.3998
#                   7d Price Change (%)  -8.0373
# Dogecoin          1h Price Change (%)   0.3276
#                   24h Price Change (%)  0.7889
#                   7d Price Change (%)  -2.3954
# TRON              1h Price Change (%)   0.1204
#                   24h Price Change (%)  1.1319
#                   7d Price Change (%)  -2.2897

# %%
df4.count()  #couting total rows in all groups
# Out:
# Values    30
# dtype: int64

# %%
df6 = df4.reset_index()   # Setting index
df6
# Out:
#                  Name               level_1  Values
# 0             Bitcoin   1h Price Change (%)  0.2375
# 1             Bitcoin  24h Price Change (%)  0.2681
# 2             Bitcoin   7d Price Change (%) -6.3021
# 3            Ethereum   1h Price Change (%)  0.1920
# 4            Ethereum  24h Price Change (%) -0.3038
# 5            Ethereum   7d Price Change (%) -7.7962
# 6              Tether   1h Price Change (%)  0.0324
# 7              Tether  24h Price Change (%) -0.0473
# 8              Tether   7d Price Change (%) -0.0800
# 9                 BNB   1h Price Change (%) -0.0399
# 10                BNB  24h Price Change (%)  0.3744
# 11                BNB   7d Price Change (%) -4.3555
# 12             Solana   1h Price Change (%)  0.0746
# 13             Solana  24h Price Change (%)  0.8911
# 14             Solana   7d Price Change (%) -2.9888
# 15               USDC   1h Price Change (%)  0.0470
# 16               USDC  24h Price Change (%)  0.0259
# 17               USDC   7d Price Change (%)  0.0640
# 18                XRP   1h Price Change (%)  0.1811
# 19                XRP  24h Price Change (%) -0.4544
# 20                XRP   7d Price Change (%) -5.1548
# 21  Lido Staked Ether   1h Price Change (%)  0.1025
# 22  Lido Staked Ether  24h Price Change (%) -0.3998
# 23  Lido Staked Ether   7d Price Change (%) -8.0373
# 24           Dogecoin   1h Price Change (%)  0.3276
# 25           Dogecoin  24h Price Change (%)  0.7889
# 26           Dogecoin   7d Price Change (%) -2.3954
# 27               TRON   1h Price Change (%)  0.1204
# 28               TRON  24h Price Change (%)  1.1319
# 29               TRON   7d Price Change (%) -2.2897

# %%
df7 = df6.rename(columns={'level_1':'Price_Trend'})  #Renaming Column Name
df7
# Out:
#                  Name           Price_Trend  Values
# 0             Bitcoin   1h Price Change (%)  0.2375
# 1             Bitcoin  24h Price Change (%)  0.2681
# 2             Bitcoin   7d Price Change (%) -6.3021
# 3            Ethereum   1h Price Change (%)  0.1920
# 4            Ethereum  24h Price Change (%) -0.3038
# 5            Ethereum   7d Price Change (%) -7.7962
# 6              Tether   1h Price Change (%)  0.0324
# 7              Tether  24h Price Change (%) -0.0473
# 8              Tether   7d Price Change (%) -0.0800
# 9                 BNB   1h Price Change (%) -0.0399
# 10                BNB  24h Price Change (%)  0.3744
# 11                BNB   7d Price Change (%) -4.3555
# 12             Solana   1h Price Change (%)  0.0746
# 13             Solana  24h Price Change (%)  0.8911
# 14             Solana   7d Price Change (%) -2.9888
# 15               USDC   1h Price Change (%)  0.0470
# 16               USDC  24h Price Change (%)  0.0259
# 17               USDC   7d Price Change (%)  0.0640
# 18                XRP   1h Price Change (%)  0.1811
# 19                XRP  24h Price Change (%) -0.4544
# 20                XRP   7d Price Change (%) -5.1548
# 21  Lido Staked Ether   1h Price Change (%)  0.1025
# 22  Lido Staked Ether  24h Price Change (%) -0.3998
# 23  Lido Staked Ether   7d Price Change (%) -8.0373
# 24           Dogecoin   1h Price Change (%)  0.3276
# 25           Dogecoin  24h Price Change (%)  0.7889
# 26           Dogecoin   7d Price Change (%) -2.3954
# 27               TRON   1h Price Change (%)  0.1204
# 28               TRON  24h Price Change (%)  1.1319
# 29               TRON   7d Price Change (%) -2.2897

# %%
df7['Price_Trend'] = df7['Price_Trend'].replace(['1h Price Change (%)','24h Price Change (%)','7d Price Change (%)'],['1h','24h','7D'])
df7
# Out:
#                  Name Price_Trend  Values
# 0             Bitcoin          1h  0.2375
# 1             Bitcoin         24h  0.2681
# 2             Bitcoin          7D -6.3021
# 3            Ethereum          1h  0.1920
# 4            Ethereum         24h -0.3038
# 5            Ethereum          7D -7.7962
# 6              Tether          1h  0.0324
# 7              Tether         24h -0.0473
# 8              Tether          7D -0.0800
# 9                 BNB          1h -0.0399
# 10                BNB         24h  0.3744
# 11                BNB          7D -4.3555
# 12             Solana          1h  0.0746
# 13             Solana         24h  0.8911
# 14             Solana          7D -2.9888
# 15               USDC          1h  0.0470
# 16               USDC         24h  0.0259
# 17               USDC          7D  0.0640
# 18                XRP          1h  0.1811
# 19                XRP         24h -0.4544
# 20                XRP          7D -5.1548
# 21  Lido Staked Ether          1h  0.1025
# 22  Lido Staked Ether         24h -0.3998
# 23  Lido Staked Ether          7D -8.0373
# 24           Dogecoin          1h  0.3276
# 25           Dogecoin         24h  0.7889
# 26           Dogecoin          7D -2.3954
# 27               TRON          1h  0.1204
# 28               TRON         24h  1.1319
# 29               TRON          7D -2.2897

# %% [markdown]
# # Visualizing Cryptocurrency Price Trends with Seaborn Point Plot

# %%
import seaborn as sb
import warnings
import matplotlib.pyplot as plt

sb.catplot(x='Price_Trend',y='Values',hue = 'Name',data=df7,kind='point')
plt.title(label='Cryptocurrency Price Trends',fontsize = 18, fontweight=2)
plt.xlabel('Time')
# warnings.filterwarnings("ignore", message=".*tight_layout.*")
# plt.tight_layout()
plt.show()
# Out:
# C:\Users\LOGIN-SOLUTIOn\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.columns
# Out:
# Index(['Name', 'Symbol', 'Current Price (USD)', 'Market Cap (USD)',
#        '24h Volume (USD)', '24h Price Change (%)', '1h Price Change (%)',
#        '7d Price Change (%)', 'Timestamp'],
#       dtype='object')

# %%
df8 = df[['Name','Current Price (USD)','Timestamp']]
df8
# Out:
#                  Name  Current Price (USD)            Timestamp
# 0             Bitcoin           54483.0000  2024-09-09 00:23:42
# 1            Ethereum            2278.6500  2024-09-09 00:23:42
# 2              Tether               1.0000  2024-09-09 00:23:42
# 3                 BNB             496.8700  2024-09-09 00:23:42
# 4              Solana             128.9400  2024-09-09 00:23:42
# 5                USDC               1.0000  2024-09-09 00:23:42
# 6                 XRP               0.5267  2024-09-09 00:23:42
# 7   Lido Staked Ether            2274.5800  2024-09-09 00:23:42
# 8            Dogecoin               0.0956  2024-09-09 00:23:42
# 9                TRON               0.1531  2024-09-09 00:23:42
# 10            Bitcoin           54483.0000  2024-09-09 00:24:36
# 11           Ethereum            2278.6500  2024-09-09 00:24:36
# 12             Tether               1.0000  2024-09-09 00:24:36
# 13                BNB             496.8700  2024-09-09 00:24:36
# 14             Solana             128.9400  2024-09-09 00:24:36
# 15               USDC               1.0000  2024-09-09 00:24:36
# 16                XRP               0.5267  2024-09-09 00:24:36
# 17  Lido Staked Ether            2274.5800  2024-09-09 00:24:36
# 18           Dogecoin               0.0956  2024-09-09 00:24:36
# 19               TRON               0.1531  2024-09-09 00:24:36
# 20            Bitcoin           54483.0000  2024-09-09 00:24:48
# 21           Ethereum            2278.6500  2024-09-09 00:24:48
# 22             Tether               1.0000  2024-09-09 00:24:48
# 23                BNB             496.8700  2024-09-09 00:24:48
# 24             Solana             128.9400  2024-09-09 00:24:48
# 25               USDC               1.0000  2024-09-09 00:24:48
# 26                XRP               0.5267  2024-09-09 00:24:48
# 27  Lido Staked Ether            2274.5800  2024-09-09 00:24:48
# 28           Dogecoin               0.0956  2024-09-09 00:24:48
# 29               TRON               0.1531  2024-09-09 00:24:48
# 30            Bitcoin           54483.0000  2024-09-09 00:25:01
# 31           Ethereum            2278.6500  2024-09-09 00:25:01
# 32             Tether               1.0000  2024-09-09 00:25:01
# 33                BNB             496.8700  2024-09-09 00:25:01
# 34             Solana             128.9400  2024-09-09 00:25:01
# 35               USDC               1.0000  2024-09-09 00:25:01
# 36                XRP               0.5267  2024-09-09 00:25:01
# 37  Lido Staked Ether            2274.5800  2024-09-09 00:25:01
# 38           Dogecoin               0.0956  2024-09-09 00:25:01
# 39               TRON               0.1531  2024-09-09 00:25:01

# %%
df9 = df8.query("Name == 'Bitcoin'")
df9
# Out:
#        Name  Current Price (USD)            Timestamp
# 0   Bitcoin           54483.0000  2024-09-09 00:23:42
# 10  Bitcoin           54483.0000  2024-09-09 00:24:36
# 20  Bitcoin           54483.0000  2024-09-09 00:24:48
# 30  Bitcoin           54483.0000  2024-09-09 00:25:01

# %% [markdown]
# # Line Plot of Cryptocurrency Prices Over Time

# %%
sb.set_theme(style="darkgrid")

sb.lineplot(x ='Timestamp', y ='Current Price (USD)', data = df9)
# Out:
# <Axes: xlabel='Timestamp', ylabel='Current Price (USD)'>
